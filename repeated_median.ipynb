# %% [markdown]
# # Repeated Median estimator
#
# 1. Ucitavanje Fish.csv dataseta, log transformacija
# 2. Implementacija Repeated Median od nule, validacija sa sklearn
# 3. Ubacivanje outlier-a
# 4. Poređenje sa najmanjim kvadratima: tabele, grafikoni, analiza rezultata (sta vec treab...)
